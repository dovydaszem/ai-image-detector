# %%
import os
import torch
import shutil
from tqdm import tqdm
from pathlib import Path
from IPython.display import FileLink
from diffusers import AutoPipelineForText2Image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/site-packages/diffusers/utils/import_utils.py:953, in _LazyModule._get_module(self, module_name)
#     952 try:
# --> 953     return importlib.import_module("." + module_name, self.__name__)
#     954 except Exception as e:
#
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/site-packages/diffusers/pipelines/cogview4/pipeline_cogview4_control.py:21
#      20 import torch
# ---> 21 from transformers import AutoTokenizer, GlmModel
#      23 from ...callbacks import MultiPipelineCallbacks, PipelineCallback
#
# ImportError: cannot import name 'GlmModel' from 'transformers' (CONDA_ENV/envs/ai_image_detector/lib/python3.12/site-packages/transformers/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/site-packages/diffusers/utils/import_utils.py:953, in _LazyModule._get_module(self, module_name)
#     952 try:
# --> 953     return importlib.import_module("." + module_name, self.__name__)
#     954 except Exception as e:
#
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/site-packages/diffusers/pipelines/auto_pipeline.py:26
#      25 from .cogview3 import CogView3PlusPipeline
# ---> 26 from .cogview4 import CogView4ControlPipeline, CogView4Pipeline
#      27 from .controlnet import (
#      28     StableDiffusionControlNetImg2ImgPipeline,
#      29     StableDiffusionControlNetInpaintPipeline,
#    (...)     36     StableDiffusionXLControlNetUnionPipeline,
#      37 )
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/site-packages/diffusers/utils/import_utils.py:943, in _LazyModule.__getattr__(self, name)
#     942 elif name in self._class_to_module.keys():
# --> 943     module = self._get_module(self._class_to_module[name])
#     944     value = getattr(module, name)
#
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/site-packages/diffusers/utils/import_utils.py:955, in _LazyModule._get_module(self, module_name)
#     954 except Exception as e:
# --> 955     raise RuntimeError(
#     956         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     957         f" traceback):\n{e}"
#     958     ) from e
#
# RuntimeError: Failed to import diffusers.pipelines.cogview4.pipeline_cogview4_control because of the following error (look up to see its traceback):
# cannot import name 'GlmModel' from 'transformers' (CONDA_ENV/envs/ai_image_detector/lib/python3.12/site-packages/transformers/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 7
#       5 from pathlib import Path
#       6 from IPython.display import FileLink
# ----> 7 from diffusers import AutoPipelineForText2Image
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/site-packages/diffusers/utils/import_utils.py:944, in _LazyModule.__getattr__(self, name)
#     942 elif name in self._class_to_module.keys():
#     943     module = self._get_module(self._class_to_module[name])
# --> 944     value = getattr(module, name)
#     945 else:
#     946     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/site-packages/diffusers/utils/import_utils.py:943, in _LazyModule.__getattr__(self, name)
#     941     value = self._get_module(name)
#     942 elif name in self._class_to_module.keys():
# --> 943     module = self._get_module(self._class_to_module[name])
#     944     value = getattr(module, name)
#     945 else:
#
# File ~/miniconda3/envs/ai_image_detector/lib/python3.12/site-packages/diffusers/utils/import_utils.py:955, in _LazyModule._get_module(self, module_name)
#     953     return importlib.import_module("." + module_name, self.__name__)
#     954 except Exception as e:
# --> 955     raise RuntimeError(
#     956         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     957         f" traceback):\n{e}"
#     958     ) from e
#
# RuntimeError: Failed to import diffusers.pipelines.auto_pipeline because of the following error (look up to see its traceback):
# Failed to import diffusers.pipelines.cogview4.pipeline_cogview4_control because of the following error (look up to see its traceback):
# cannot import name 'GlmModel' from 'transformers' (CONDA_ENV/envs/ai_image_detector/lib/python3.12/site-packages/transformers/__init__.py)

# %%
# Load the pipeline in float16
model = "stabilityai/sdxl-turbo"
pipe = AutoPipelineForText2Image.from_pretrained(model, torch_dtype=torch.float16, variant="fp16")
pipe.enable_model_cpu_offload()
# Out:
# model_index.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/704 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/565 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/459 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/575 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/586 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# text_encoder_2/model.fp16.safetensors:   0%|          | 0.00/1.39G [00:00<?, ?B/s]
# text_encoder/model.fp16.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/607 [00:00<?, ?B/s]
# unet/diffusion_pytorch_model.fp16.safete(…):   0%|          | 0.00/5.14G [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.fp16.safeten(…):   0%|          | 0.00/167M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!

# %%
captions_fname = Path.cwd() / "images" / "captions.txt"
# !rm -rf /kaggle/working/gen
os.makedirs("/kaggle/working/gen", exist_ok=True)

with open(captions_fname, "r") as f:
    for i, line in enumerate(f):
        prompt = line.rstrip("\n")
        img = pipe(prompt=prompt, num_inference_steps=1, guidance_scale=0.0).images[0]
        img.save(f"/kaggle/working/gen/{str(i).zfill(4)}.jpg")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !rm /kaggle/working/gen.zip
shutil.make_archive("/kaggle/working/gen", 'zip', "/kaggle/working/gen")
FileLink(r'gen.zip')
